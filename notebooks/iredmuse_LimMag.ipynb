# %%
# %load_ext autoreload 
# %autoreload 2

from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
from astropy.io import fits
from astropy.table import Table
import numpy as np
from datetime import datetime
from pyetc_ifs import ETC,WST,iredMUSE, MUSE, blueMUSE, get_seeing_fwhm, __version__
from scipy.optimize import brentq
from tqdm.notebook import tqdm
import json, pickle
import os
plt.rcParams.update({'font.size': 12})
path_to_images = "/home/nbouche/Python_git/pyetc_iredmuse/images/"
print(f"pyetc_ifs version {__version__}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# pyetc_ifs version 0.2

# %%
wst = WST(log = 'WARNING', skip_dataload = False)
wst.info()
instru=wst
ifs_channels=np.array(instru.ifs['channels'])

# %%
muse=MUSE()
muse.info()
# Out:
# [INFO] Reading ifs full into self._transdata
# [INFO] ETC version 0.2 release date 14 July 2026
# [INFO] 	- Initial version
# [INFO] Telescope Based on Prelim Concept version 26/06/2026
# [INFO] Diameter: 8.00 m Eff. Area IFS: 48.5 m2
# [INFO] IFS type IFS Channel full
# [INFO] 	 Throughput model: Throughput estimations by Nicolas Bouché
# [INFO] 	 Configuration version: 14/07/2026
# [INFO] 	 Spaxel size: 0.20 arcsec Image Quality tel and ins fwhm: 0.10 and 0.13 arcsec beta: 2.80
# [INFO] 	 Wavelength range [4800. 9300.] A step 1.25 A LSF 2.2 pix Npix 3601
# [INFO] 	 Instrument transmission peak 0.27 at 7060 - min 0.11 at 9300
# [INFO] 	 Detector RON 2.6 e- Dark 3.0 e-/h

# %%
redmuse=iredMUSE()
redmuse.info()
# Out:
# [INFO] Reading ifs zband into self._transdata
# [INFO] Reading ifs Jband into self._transdata
# [INFO] Reading ifs zJband into self._transdata
# [INFO] ETC version 0.2 release date 14 July 2026
# [INFO] 	- bug fix in transmission curve
# [INFO] Telescope Based on Prelim Concept version 26/06/2026
# [INFO] Diameter: 8.00 m Eff. Area IFS: 48.5 m2
# [INFO] IFS type IFS Channel zband
# [INFO] 	 Throughput model: Throughput estimations by Nicolas Bouché
# [INFO] 	 Configuration version: 14/07/2026
# [INFO] 	 Spaxel size: 0.22 arcsec Image Quality tel and ins fwhm: 0.10 and 0.13 arcsec beta: 2.80
# [INFO] 	 Wavelength range [ 9500. 11300.] A step 0.90 A LSF 2.2 pix Npix 2001
# [INFO] 	 Instrument transmission peak 0.32 at 10667 - min 0.30 at 9500
# [INFO] 	 Detector RON 7.0 e- Dark 72.0 e-/h
# [INFO] IFS type IFS Channel Jband
# [INFO] 	 Throughput model: Throughput estimations by Nicolas Bouché
# [INFO] 	 Configuration version: 14/07/2026
# [INFO] 	 Spaxel size: 0.22 arcsec Image Quality tel and ins fwhm: 0.10 and 0.13 arcsec beta: 2.80
# [INFO] 	 Wavelength range [11300. 13000.] A step 1.00 A LSF 2.5 pix Npix 1701
# [INFO] 	 Instrument transmission peak 0.33 at 12510 - min 0.32 at 11300
# [INFO] 	 Detector RON 7.0 e- Dark 72.0 e-/h
# [INFO] IFS type IFS Channel zJband
# [INFO] 	 Throughput model: Throughput estimations by Nicolas Bouché
# [INFO] 	 Configuration version: 14/07/2026
# [INFO] 	 Spaxel size: 0.22 arcsec Image Quality tel and ins fwhm: 0.10 and 0.13 arcsec beta: 2.80
# [INFO] 	 Wavelength range [ 9330.  12499.5] A step 1.50 A LSF 2.5 pix Npix 2114
# [INFO] 	 Instrument transmission peak 0.33 at 11595 - min 0.27 at 9330
# [INFO] 	 Detector RON 7.0 e- Dark 72.0 e-/h

# %%
instru=redmuse
#ifs_channels=np.array([instru.ifs['channels'][-1]])
ifs_channels=instru.ifs['channels']
ifs_channels
# Out:
# ['zband', 'Jband', 'zJband']

# %%
def get_specinfo(full_obs, inst=instru):
    insfam = getattr(inst, full_obs["INS"])
    ins = insfam[full_obs["CH"]]
    lsf = ins['lsfpix']*ins['dlbda']
    dl = ins['dlbda']
    dr = full_obs['COADD_WL']*ins['dlbda']
    l1,l2 = ins['lbda1'],ins['lbda2']
    return dr,lsf,l1,l2,dl,ins

# %%
for ch in ifs_channels:
    ins=instru.ifs[ch]
    lstep_1 = ins['wave'].get_step()
    lstep_2 = ins['dlbda']
    print(ch,lstep_1,lstep_2)
# Out:
# zband 0.9 0.9
# Jband 1.0 1.0
# zJband 1.5 1.5

# %% [markdown]
# # Transmission

# %% [raw]
# print(f"Reading {instru.name} channel {ch}")
# tab=Table.read(f'../pyetc_ifs/data/{instru.name.lower()}/ifs_{ch}_noatm.fits')
# tab=Table.read("/home/nbouche/Nextcloud/Instru/irMUSE/irMUSE-ETC/iredmuse_Jband_noatm.fits")
#
# only_instr = tab['total'] / (tab['detector_QE'] * tab['telescope'])
#
#
# plt.plot(tab['wave'],tab['telescope'],label='telescope')
# plt.plot(tab['wave'],tab['detector_QE'],label='detector')
# plt.plot(tab['wave'],only_instr,label='only ins')
# plt.plot(tab['wave'],tab['total'],label='Instru+tel+Det/Full trans no Atm')
# plt.legend()

# %%
ch='zJband'
for ch in ifs_channels:
    ins=instru.ifs[ch]
    plt.plot(ins['wave'].coord(),ins['telescope'].data,label='telescope')
    plt.plot(ins['wave'].coord(),ins['QE'].data,label='QE')
    plt.plot(ins['wave'].coord(),ins['total_instrumental'].data,label='Instr only')
    plt.plot(ins['wave'].coord(),ins['instrans'].data,label='Instru+tel+QE')
    plt.legend()

# %% [markdown]
# def optim_snr2(con, im, spe, lbda, coadd0, inst=instru):
#     global niter
#     snr1 = 0
#     for coadd in np.arange(coadd0, 1, -1):
#         niter += 1
#         inst.obs['ima_coadd'] = coadd
#         res_snr2 = inst.snr_at_wave(con, im, spe, wave_target=lbda)
#         snr2 = res_snr2['snr_aperture']
#         #print(coadd, snr2)
#         if snr2 < snr1:
#             break
#         coadd1 = coadd
#         snr1 = snr2
#     for coadd in np.arange(coadd0+1, 20):
#         niter += 1
#         inst.obs['ima_coadd'] = coadd
#         res_snr2 = inst.snr_at_wave(con, im, spe, wave_target=lbda)
#         snr2 = res_snr2['snr_aperture']
#         #print(coadd, snr2)
#         if snr2 < snr1:
#             break
#         coadd1 = coadd
#         snr1 = snr2
#     return snr1,coadd1

# %% [markdown]
# # LSF

# %%
def lsf_resolution(wavelength_AA, ins=instru) -> float:
    """
    wavelength_AA : float | nd.array
    return the spectral resolution R = lambda / delta_lambda of the LSF at a given wavelength in Angstrom
    """

    lstep_AA = ins['dlbda']
    fwhm_AA = ins['lsfpix'] * lstep_AA

    return wavelength_AA / float(fwhm_AA)

# %%
for ch in ifs_channels:
    ins=instru.ifs[ch]
    lstep_AA = ins['wave'].get_step()
    fwhm_AA = ins['lsfpix'] * lstep_AA
    
    lmin,lmax=ins['wave'].get_range()

    lmean=(lmin+lmax)/2.0
    lstep_kms=lstep_AA/lmean*3e5
    fwhm_kms=fwhm_AA/lmean*3e5
    
    print("LSF Channel {} \n  step={:0.1f}AA ={:.0f}km/s \n  FWHM={:.2f}AA ={:.0f}km/s".format(ch,lstep_AA,lstep_kms,fwhm_AA,fwhm_kms))
# Out:
# LSF Channel zband
#   step=0.9AA =26km/s
#   FWHM=1.98AA =57km/s
# LSF Channel Jband
#   step=1.0AA =25km/s
#   FWHM=2.50AA =62km/s
# LSF Channel zJband
#   step=1.5AA =41km/s
#   FWHM=3.75AA =103km/s

# %%
for ch in ifs_channels:
    ins=instru.ifs[ch]
    l1,l2=ins['wave'].get_range()
    dl=ins['wave'].get_step()
    print(" {} ".format(ch),(l2-l1)/dl)
# Out:
#  zband  2000.0
#  Jband  1700.0
#  zJband  2113.0

# %%
for ch in ifs_channels:
    ins=instru.ifs[ch]
    wave=ins['wave'].coord()
    R=lsf_resolution(wave, ins)
    plt.plot(wave,R,label='R {}'.format(ch))
plt.legend()
plt.plot(wave,ins['sky'][0]['abs'].data*3000,label='sky',c='grey')
plt.savefig(f"{path_to_images}/{instru.name}_resolution.png")

# %% [markdown]
# # Input Parameters

# %%
common_obs = {
    "NDIT": 10,
    "DIT": 1000,    
    "PWV": 1,
    "AM": 1.2,
    "SKYCALC": False,   
    "MAG_SYS": 'AB',
    "MAG_FIL": 'rSDSS',    
    "Z": 0,   
    "SEE": 0.8,
}
#mag limit
ifs_obs_ps = {
    "INS": "ifs",
    "GLAO": False,
    "Obj_Spat_Dis": 'ps', 
    "Obj_SED": 'uniform',   
    "COADD_WL": 3,  
    "SNR_REQ" : 10,
    "COADD_XY": 'best',
}
#line emission
ifs_obs_psl = {
    "INS": "ifs",
    "GLAO": False,
    "Obj_Spat_Dis": 'ps', 
    "Obj_SED": 'line',   
    "SEL_FWHM": 5, #line FWHM in A / 150km/s at 1mu
    "COADD_WL": 3,  
    "SNR_REQ" : 10,
    "COADD_XY": 'best',
}
#SB limit
ifs_obs_sb = {
    "INS": "ifs",
    "Obj_Spat_Dis": 'sb', 
    "Obj_SED": 'uniform',   
    "COADD_WL": 3,    
    "COADD_XY": 16,
    "SNR_REQ" : 3,
}
moslr_obs_ps = {
    "INS": "moslr",
    "SEE": 0.75,
    "Obj_SED": 'uniform',  
    "Obj_Spat_Dis": 'ps',   
    "COADD_WL": 7,
    "OBJ_FIB_DISP": 0.15,
    "SNR_REQ" : 3,
}
moshr_obs_ps = {
    "INS": "moshr",
    "SEE": 0.75,
    "Obj_SED": 'uniform',  
    "Obj_Spat_Dis": 'ps',   
    "COADD_WL": 4,
    "OBJ_FIB_DISP": 0.15,
    "SNR_REQ" : 3,
}

# %% [markdown]
# # IFS point source limiting magnitude

# %%
def maglim_ifs(full_obs, lbda, snr, mags, dmag=0.1, dsnr=0.1):
    mag = brentq(zeromag_ifs, mags[0], mags[1], xtol=dsnr, args=(snr, full_obs, lbda))
    return mag
def zeromag_ifs(mag, snr0, full_obs, lbda, inst=instru):
    full_obs['OBJ_MAG'] = mag
    con, ob, spe, im, spe_input = inst.build_obs_full(full_obs)
    res = inst.snr_at_wave(con, im, spe, lbda)
    return res['snr_aperture']-snr0

# %%
full_obs = common_obs | ifs_obs_ps    
mags = [20,30]
snr = full_obs["SNR_REQ"]
ifs_psmag = []
for fli in [0,0.5,1]:
    dm = dict(fli=fli, ins='ifs')
    full_obs["FLI"] = fli
    print(f"Moon : {fli}")
    dlim = []
    for ch in ifs_channels:
        full_obs['CH'] = ch
        con, ob, spe, im, spe_input = instru.build_obs_full(full_obs)
        dr,lsf,l1,l2,dl,ins = get_specinfo(full_obs)
        integ = full_obs['NDIT']*full_obs['DIT']/3600
        print(f"Instrument {full_obs['INS']} Channel {full_obs['CH']} Version {ins['version']}")
        print(f"Limiting magnitude for S/N = {snr} by resolving element in {integ} hour(s) ({full_obs['NDIT']} exp)")
        print(f"Resolving element {dr} A ({full_obs['COADD_WL']} pix) LSF {lsf} A")
        nwaves = int(((l2-l1)/dr))
        waves = np.linspace(l1+20,l2-20,nwaves)
        lmag = []
        for lbda in tqdm(waves):  
            try:
                mag = maglim_ifs(full_obs, lbda, snr, mags)
            except:
                mag = maglim_ifs(full_obs, lbda, snr, mags=[10,30])
            #print(f"lbda {lbda:.1f} mag {mag:.2f} niter {niter}")
            lmag.append(mag)
            mags = [mag-0.5,mag+0.5]
        dlim.append(dict(chan=ch, waves=waves.tolist(), lmag=lmag, snr=snr, integ=integ, nexp=full_obs['NDIT'], dr=dr, dl=dl, 
                            lbda=(l1,l2), lsf=lsf, pixspec=full_obs['COADD_WL'], version=ins['version']))
    dm['dlim'] = dlim
    ifs_psmag.append(dm)
# Out:
# Moon : 0
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/666 [00:00<?, ?it/s]
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/566 [00:00<?, ?it/s]
# Instrument ifs Channel zJband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 4.5 A (3 pix) LSF 3.75 A
#   0%|          | 0/704 [00:00<?, ?it/s]
# Moon : 0.5
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/666 [00:00<?, ?it/s]
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/566 [00:00<?, ?it/s]
# Instrument ifs Channel zJband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 4.5 A (3 pix) LSF 3.75 A
#   0%|          | 0/704 [00:00<?, ?it/s]
# Moon : 1
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/666 [00:00<?, ?it/s]
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/566 [00:00<?, ?it/s]
# Instrument ifs Channel zJband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.7777777777777777 hour(s) (10 exp)
# Resolving element 4.5 A (3 pix) LSF 3.75 A
#   0%|          | 0/704 [00:00<?, ?it/s]

# %%
fig,ax = plt.subplots(1,1,figsize=(10,4))
labs = []
for d,c in zip(ifs_psmag[0]['dlim'], ['blue', 'red', 'orange']):
    lab = f"{d['chan']} chan dark-time S/N {snr} by {d['dr']:.1f}A ({d['pixspec']}pix)"
    labs.append(lab)
    muJy=10**((23.9-np.array(d['lmag']))/2.5)
    ax.plot(d['waves'], muJy, color=c, ls='-')
for d,c in zip(ifs_psmag[1]['dlim'], ['blue', 'red', 'orange']):
    muJy=10**((23.9-np.array(d['lmag']))/2.5)
    ax.plot(d['waves'], muJy, color=c, ls='--')
for d,c in zip(ifs_psmag[2]['dlim'], ['blue', 'red', 'orange']):
    muJy=10**((23.9-np.array(d['lmag']))/2.5)
    ax.plot(d['waves'], muJy, color=c, ls=':')
ax.set_xlabel('Wavelength (A)')
ax.set_ylabel(r'$F_{\nu}$ ($\mu$Jy)')
see = 'GLAO' if full_obs['GLAO'] else f"seeing {ob['seeing']} arcsec"
integ = full_obs['NDIT']*full_obs['DIT']/1000
snr_req=full_obs['SNR_REQ']
ax.set_title(f"IFS {instru.name} mag lim S/N={snr_req} in {integ:.0f}ksec ({full_obs['NDIT']} exp) - {see}, airmass {full_obs['AM']}, ETC {__version__}");
ax.grid()
custom_lines = [Line2D([0], [0], color='blue', lw=1),
                Line2D([0], [0], color='red', lw=1),
                Line2D([0], [0], color='black', ls='--', lw=1),
                Line2D([0], [0], color='black', ls=':', lw=1),
               ]
labs.append(f"grey time")
labs.append(f"bright time")
ax.legend(custom_lines, labs, fontsize=10,loc=1)
today = datetime.now().strftime("%Y-%m-%d")
ax.text(0.02, 0.90, f"Computed {today}", transform=ax.transAxes, size=10)
# Out:
# Text(0.02, 0.9, 'Computed 2026-07-24')

# %%
today = datetime.now().strftime("%Y-%m-%d")
outfig = os.path.join(path_to_images,f"{today}_{instru.name}_IFS_limiting_Jy.jpg")
fig.savefig(outfig, bbox_inches='tight')
print(f"Saved file {outfig}")

outres = os.path.join(path_to_images,f"{today}_{instru.name}_IFS_limiting_Jy.json")
with open(outres, "w") as f:
    json.dump(ifs_psmag, f, indent=2)
print(f"Saved file {outres}")
# Out:
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_limiting_Jy.jpg
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_limiting_Jy.json

# %%
fig,ax = plt.subplots(1,1,figsize=(10,4))
labs = []
for d,c in zip(ifs_psmag[0]['dlim'], ['blue', 'red', 'orange']):
    lab = f"{d['chan']} chan dark-time S/N {snr} by {d['dr']:.1f}A ({d['pixspec']}pix) v.{d['version']}"
    labs.append(lab)
    ax.plot(d['waves'], d['lmag'], color=c, ls='-')
for d,c in zip(ifs_psmag[1]['dlim'], ['blue', 'red', 'orange']):
    ax.plot(d['waves'], d['lmag'], color=c, ls='--')
for d,c in zip(ifs_psmag[2]['dlim'], ['blue', 'red', 'orange']):
    ax.plot(d['waves'], d['lmag'], color=c, ls=':')
ax.set_xlabel('Wavelength (A)')
ax.set_ylabel('AB magnitude (r SDSS)')
see = 'GLAO' if full_obs['GLAO'] else f"seeing {ob['seeing']} arcsec"
integ = full_obs['NDIT']*full_obs['DIT']/1000
snr_req=full_obs['SNR_REQ']
ax.set_title(f"IFS {instru.name} mag lim S/N{snr_req} in {integ:.0f}ksec ({full_obs['NDIT']} exp) - {see}, airmass {full_obs['AM']}, ETC {__version__}");
ax.grid()
custom_lines = [Line2D([0], [0], color='blue', lw=1),
                Line2D([0], [0], color='red', lw=1),
                Line2D([0], [0], color='black', ls='--', lw=1),
                Line2D([0], [0], color='black', ls=':', lw=1),
               ]
labs.append(f"grey time")
labs.append(f"bright time")
ax.legend(custom_lines, labs, fontsize=10)
today = datetime.now().strftime("%Y-%m-%d")
ax.text(0.02, 0.90, f"Computed {today}", transform=ax.transAxes, size=10)
# Out:
# Text(0.02, 0.9, 'Computed 2026-07-24')

# %%
today = datetime.now().strftime("%Y-%m-%d")
outfig = os.path.join(path_to_images,f"{today}_{instru.name}_IFS_limiting_mag.jpg")
fig.savefig(outfig, bbox_inches='tight')
print(f"Saved file {outfig}")

outres = os.path.join(path_to_images,f"{today}_{instru.name}_IFS_limiting_mag.json")
with open(outres, "w") as f:
    json.dump(ifs_psmag, f, indent=2)
print(f"Saved file {outres}")
# Out:
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_limiting_mag.jpg
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_limiting_mag.json

# %% [markdown]
# # IFS surface brightness limiting flux

# %%
def maglim_ifs_sb(full_obs, lbda, snr, mags, dmag=0.1, dsnr=0.1):
    mag = brentq(zeromag_ifs_sb, mags[0], mags[1], xtol=dsnr, args=(snr, full_obs, lbda))
    return mag
def zeromag_ifs_sb(mag, snr0, full_obs, lbda, inst=instru):
    full_obs['OBJ_MAG'] = mag
    con, ob, spe, im, spe_input = inst.build_obs_full(full_obs)
    res = inst.snr_at_wave(con, im, spe, lbda)
    return res['snr_aperture']-snr0

# %%
full_obs = common_obs | ifs_obs_sb    
mags = [10,30]
snr = full_obs["SNR_REQ"]
ifs_sb = []
for fli in [0,0.5,1]:
    print(f"Moon : {fli}")
    dm = dict(fli=fli, ins='ifs')
    full_obs["FLI"] = fli
    dlim = []
    for ch in ifs_channels:
        full_obs['CH'] = ch
        con, ob, spe, im, spe_input = instru.build_obs_full(full_obs)
        dr,lsf,l1,l2,dl,ins = get_specinfo(full_obs)
        integ = full_obs['NDIT']*full_obs['DIT']/3600
        print(f"Instrument {full_obs['INS']} Channel {full_obs['CH']} Version {ins['version']}")
        print(f"Limiting magnitude for S/N = {snr} by resolving element in {integ:.2f} hour(s) ({full_obs['NDIT']} exp)")
        print(f"Resolving element {dr} A ({full_obs['COADD_WL']} pix) LSF {lsf} A")
        nwaves = int(((l2-l1)/dr)/2)
        waves = np.linspace(l1+20,l2-20,nwaves)
        lmag = []
        for lbda in tqdm(waves):  
            try:
                mag = maglim_ifs_sb(full_obs, lbda, snr, mags)
            except:
                mag = maglim_ifs_sb(full_obs, lbda, snr, mags=[10,30])
            #print(f"lbda {lbda:.1f} mag {mag:.2f} niter {niter}")
            lmag.append(mag)
            mags = [mag-0.5,mag+0.5]
        dlim.append(dict(chan=ch, waves=waves.tolist(), lmag=lmag, snr=snr, integ=integ, nexp=full_obs['NDIT'], dr=dr, dl=dl, 
                            lbda=(l1,l2), lsf=lsf, pixspec=full_obs['COADD_WL'], version=ins['version']))
    dm['dlim'] = dlim
    ifs_sb.append(dm)
# Out:
# Moon : 0
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/333 [00:00<?, ?it/s]
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/283 [00:00<?, ?it/s]
# Instrument ifs Channel zJband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 4.5 A (3 pix) LSF 3.75 A
#   0%|          | 0/352 [00:00<?, ?it/s]
# Moon : 0.5
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/333 [00:00<?, ?it/s]
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/283 [00:00<?, ?it/s]
# Instrument ifs Channel zJband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 4.5 A (3 pix) LSF 3.75 A
#   0%|          | 0/352 [00:00<?, ?it/s]
# Moon : 1
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/333 [00:00<?, ?it/s]
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/283 [00:00<?, ?it/s]
# Instrument ifs Channel zJband Version 14/07/2026
# Limiting magnitude for S/N = 3 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 4.5 A (3 pix) LSF 3.75 A
#   0%|          | 0/352 [00:00<?, ?it/s]

# %%
fig,ax = plt.subplots(1,1,figsize=(10,4))
labs = []
for d,c in zip(ifs_sb[0]['dlim'], ['blue','red']):
    lab = f"{d['chan']} chan dark-time S/N {snr} by {d['dr']:.1f}A ({d['pixspec']}pix) v.{d['version']}"
    labs.append(lab)
    ax.plot(d['waves'], d['lmag'], color=c, ls='-')
for d,c in zip(ifs_sb[1]['dlim'], ['blue','red']):
    ax.plot(d['waves'], d['lmag'], color=c, ls='--')
for d,c in zip(ifs_sb[2]['dlim'], ['blue','red']):
    ax.plot(d['waves'], d['lmag'], color=c, ls=':')
ax.set_xlabel('Wavelength (A)')
ax.set_ylabel('SB AB magnitude (r SDSS) by arcsec2')
integ = full_obs['NDIT']*full_obs['DIT']/1000
snr_req=full_obs['SNR_REQ']
ax.set_title(f"IFS {instru.name} SB mag lim S/N {snr_req} in {integ:.0f} ksec ({full_obs['NDIT']} exp) {full_obs['AM']}, ETC {__version__}");
ax.grid()
custom_lines = [Line2D([0], [0], color='blue', lw=1),
                Line2D([0], [0], color='red', lw=1),
                Line2D([0], [0], color='black', ls='--', lw=1),
                Line2D([0], [0], color='black', ls=':', lw=1),
               ]
labs.append(f"grey time")
labs.append(f"bright time")
ax.legend(custom_lines, labs, fontsize=10)
today = datetime.now().strftime("%Y-%m-%d")
ax.text(0.02, 0.90, f"Computed {today}", transform=ax.transAxes, size=10)
# Out:
# Text(0.02, 0.9, 'Computed 2026-07-24')

# %%
today = datetime.now().strftime("%Y-%m-%d")
outfig = os.path.join(file_dir,f"{today}_{instru.name}_IFS_SBlimiting_mag.jpg")
fig.savefig(outfig, bbox_inches='tight')
print(f"Saved file {outfig}")

outres = os.path.join(file_dir,f"{today}_{instru.name}_IFS_SBlimiting_mag.json")
with open(outres, "w") as f:
    json.dump(ifs_sb, f, indent=2)
print(f"Saved file {outres}")
# Out:
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_SBlimiting_mag.jpg
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_SBlimiting_mag.json

# %%
fig,ax = plt.subplots(1,1,figsize=(10,4))
labs = []
for d,c in zip(ifs_sb[0]['dlim'], ['blue','red', 'orange']):
    lab = f"{d['chan']} chan dark-time S/N {snr} by {d['dr']:.1f}A ({d['pixspec']}pix) v.{d['version']}"
    labs.append(lab)
    muJy=10**((23.9-np.array(d['lmag']))/2.5)
    flam=muJy*3e18/np.array(d['waves'])**2*1e-23*1e-6
    ax.plot(d['waves'], flam, color=c, ls='-')
for d,c in zip(ifs_sb[1]['dlim'], ['blue','red']):
    muJy=10**((23.9-np.array(d['lmag']))/2.5)
    flam=muJy*3e18/np.array(d['waves'])**2*1e-23*1e-6
    ax.plot(d['waves'], flam, color=c, ls='--')
for d,c in zip(ifs_sb[2]['dlim'], ['blue','red', 'orange']):
    muJy=10**((23.9-np.array(d['lmag']))/2.5)
    flam=muJy*3e18/np.array(d['waves'])**2*1e-23*1e-6
    ax.plot(d['waves'], flam, color=c, ls=':')
ax.set_xlabel('Wavelength (A)')
ax.set_ylabel('erg/s/cm2/AA/arcsec2')
integ = full_obs['NDIT']*full_obs['DIT']/1000
snr_req=full_obs['SNR_REQ']
ax.set_title(f"IFS {instru.name} SB mag lim S/N {snr_req} in {integ:.0f} ksec ({full_obs['NDIT']} exp) {full_obs['AM']}, ETC {__version__}");
ax.grid()
custom_lines = [Line2D([0], [0], color='blue', lw=1),
                Line2D([0], [0], color='red', lw=1),
                Line2D([0], [0], color='black', ls='--', lw=1),
                Line2D([0], [0], color='black', ls=':', lw=1),
               ]
labs.append(f"grey time")
labs.append(f"bright time")
ax.legend(custom_lines, labs, fontsize=10)
ax.set_ylim([0,0.5e-18])
today = datetime.now().strftime("%Y-%m-%d")
ax.text(0.02, 0.90, f"Computed {today}", transform=ax.transAxes, size=10)
# Out:
# Text(0.02, 0.9, 'Computed 2026-07-24')

# %%
today = datetime.now().strftime("%Y-%m-%d")
outfig = os.path.join(file_dir,f"{today}_{instru.name}_IFS_SBlimiting_cgs.jpg")
fig.savefig(outfig, bbox_inches='tight')
print(f"Saved file {outfig}")

outres = os.path.join(file_dir,f"{today}_{instru.name}_IFS_SBlimiting_cgs.json")
with open(outres, "w") as f:
    json.dump(ifs_sb, f, indent=2)
print(f"Saved file {outres}")
# Out:
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_SBlimiting_cgs.jpg
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_SBlimiting_cgs.json

# %% [markdown]
# # IFS limiting emission flux

# %%
def fluxlim_ifs(full_obs, lbda, snr, fluxes, dmag=0.1, dsnr=0.1):
    flux = brentq(zeroflux_ifs, fluxes[0], fluxes[1], xtol=dsnr, args=(snr, full_obs, lbda))
    return flux*1.e-20
def zeroflux_ifs(flux, snr0, full_obs, lbda, inst=instru):
    full_obs['SEL_FLUX'] = flux*1.e-20
    full_obs['SEL_CWAV'] = lbda
    con, ob, spe, im, spe_input = inst.build_obs_full(full_obs)
    res = inst.snr_from_source(con, im, spe)
    spsignal = res['spec']['nph_source']
    spnoise = res['spec']['noise']['tot']
    snrmax = snr_sum(spsignal,spnoise)
    #print(flux,snrmax)
    return snrmax-snr0

# %%
def snr_sum(signal, noise):
    signal = signal.data
    noise = noise.data
    variance = noise**2
    mask = variance > 0
    s = signal[mask]
    v = variance[mask]
    snr = np.sum(s) / np.sqrt(np.sum(v))
    return snr

# %%
full_obs = common_obs | ifs_obs_psl   
snr = full_obs["SNR_REQ"]
fluxes = [1,100000]
ifs_line = []
for fli in [0,0.5,1]:
    print(f"Moon : {fli}")
    dm = dict(fli=fli, ins='ifs')
    full_obs["FLI"] = fli
    dlim = []
    for ch in ifs_channels:
        full_obs['CH'] = ch
        dr,lsf,l1,l2,dl,ins = get_specinfo(full_obs)
        integ = full_obs['NDIT']*full_obs['DIT']/3600
        print(f"Instrument {full_obs['INS']} Channel {full_obs['CH']} Version {ins['version']}")
        print(f"Limiting magnitude for S/N = {snr} by resolving element in {integ:.2f} hour(s) ({full_obs['NDIT']} exp)")
        print(f"Resolving element {dr} A ({full_obs['COADD_WL']} pix) LSF {lsf} A")
        nwaves = int(((l2-l1)/dr)/10)
        waves = np.linspace(l1+20,l2-20,nwaves)
        lmag = []
        for lbda in tqdm(waves): 
            try:
                flux = fluxlim_ifs(full_obs, lbda, snr, fluxes)
            except:
                flux = fluxlim_ifs(full_obs, lbda, snr, fluxes=[1,100000])
            #print(f"lbda {lbda:.1f} mag {mag:.2f} niter {niter}")
            lmag.append(flux)
            fluxes = [flux*1.e20/2,flux*1.e20*2]
            #print (flux,fluxes)
        dlim.append(dict(chan=ch, waves=waves.tolist(), lmag=lmag, snr=snr, integ=integ, nexp=full_obs['NDIT'], dr=dr, dl=dl, 
                            lbda=(l1,l2), lsf=lsf, pixspec=full_obs['COADD_WL'], version=ins['version']))
    dm['dlim'] = dlim
    ifs_line.append(dm)
# Out:
# Moon : 0
# Instrument ifs Channel zband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 2.7 A (3 pix) LSF 1.9800000000000002 A
#   0%|          | 0/66 [00:00<?, ?it/s]
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9520.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 5 (at 9520.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9520.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9520.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9520.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9520.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9547.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9547.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9547.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9547.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9547.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9574.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9574.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9574.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9574.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9574.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9601.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9601.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9601.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9601.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9601.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9628.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9628.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9628.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9628.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9628.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9655.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9655.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9655.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9655.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9655.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9682.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9682.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9682.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9682.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9682.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9709.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9709.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9709.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9709.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9709.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9736.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9736.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9736.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9736.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9736.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9763.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9763.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9763.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9763.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9763.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9790.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9790.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9790.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9790.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9790.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9817.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9817.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9817.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9817.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9817.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9872.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9872.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9872.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9872.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9872.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9899.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9899.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9899.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9899.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9899.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9926.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9926.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9926.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9926.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9926.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9953.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9953.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9953.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9953.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9953.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9980.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9980.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9980.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9980.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 9980.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10007.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10007.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10007.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10007.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10007.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10034.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10034.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10034.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10034.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10034.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10061.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10061.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10061.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10061.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10061.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10088.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10088.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10088.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10088.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10088.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10115.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10115.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10115.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10115.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10115.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10142.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10142.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10142.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10142.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10142.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10169.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10169.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10169.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10169.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10169.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10196.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10196.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10196.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10196.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10196.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10224.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10224.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10224.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10224.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10224.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10251.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10251.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10251.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10251.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10251.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10278.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10278.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10278.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10278.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10278.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10305.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10305.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10305.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10305.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10305.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10332.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10332.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10332.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10332.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10332.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10359.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10359.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10359.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10359.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10359.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10386.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10386.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10386.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10386.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10386.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10413.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10413.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10413.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10413.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10413.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10440.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10440.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10440.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10440.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10440.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10467.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10467.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10467.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10467.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10467.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10494.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10494.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10494.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10494.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10494.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10521.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10521.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10521.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10521.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10521.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10548.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10548.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10548.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10548.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10548.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10576.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10576.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10576.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10576.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10576.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10603.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10603.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10603.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10603.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10603.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10630.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10630.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10630.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10630.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10630.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10657.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10657.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10657.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10657.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10657.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10684.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10684.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10684.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10684.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10684.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10711.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10711.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10711.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10711.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10711.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10738.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10738.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10738.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10738.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10738.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10765.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10765.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10765.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10765.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10765.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10792.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10792.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10792.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10792.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10792.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10819.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10819.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10819.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10819.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10846.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10846.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10846.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10846.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10846.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 6 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10873.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10900.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10900.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10900.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10900.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10900.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10928.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10928.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10928.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10928.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10928.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10955.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10955.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10955.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10955.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10955.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10982.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10982.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10982.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10982.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 10982.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11009.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11009.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11009.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11009.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11009.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11036.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11036.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11036.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11036.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11036.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11063.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11063.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11063.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11063.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11063.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11090.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11090.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11090.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11090.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11090.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11117.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11117.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11117.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11117.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11117.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11144.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11144.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11144.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11144.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11144.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11171.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11171.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11171.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11171.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11171.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11198.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11198.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11198.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11198.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11198.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11225.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11225.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11225.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11225.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11225.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11252.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11252.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11252.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11252.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11252.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11280.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11280.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11280.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11280.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11280.0 AA, initial guess=4)
# Instrument ifs Channel Jband Version 14/07/2026
# Limiting magnitude for S/N = 10 by resolving element in 2.78 hour(s) (10 exp)
# Resolving element 3.0 A (3 pix) LSF 2.5 A
#   0%|          | 0/56 [00:00<?, ?it/s]
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11320.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11320.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11320.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11320.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11320.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11350.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11350.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11350.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11350.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11350.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 6 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11380.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11410.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11410.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11410.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11410.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11410.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11440.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11470.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11470.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11470.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11470.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11470.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11501.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11501.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11501.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11501.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11501.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11531.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11531.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11531.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11531.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11531.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11561.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11561.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11561.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11561.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11561.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11591.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11591.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11591.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11591.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11591.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11621.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11621.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11621.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11621.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11621.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11652.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11652.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11652.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11652.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11652.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11682.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11682.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11682.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11682.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11682.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11712.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11712.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11712.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11712.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11712.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11742.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11742.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11742.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11742.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11742.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11772.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11772.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11772.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11772.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11772.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11802.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11802.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11802.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11802.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11802.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11833.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11833.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11833.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11833.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11833.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11863.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11863.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11863.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11863.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11863.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11893.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11893.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11893.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11893.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11893.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11923.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11923.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11923.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11923.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11923.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11953.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11953.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11953.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11953.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11953.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11984.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11984.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11984.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11984.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11984.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12014.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12014.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12014.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12014.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12014.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12044.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12044.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12044.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12044.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12044.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12074.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12074.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12074.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12074.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12074.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 7 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12104.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12134.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12134.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12134.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12134.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12134.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 7 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12165.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12195.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12195.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12195.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12195.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12195.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12225.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12225.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12225.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12225.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12225.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12255.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12255.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12255.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12255.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12255.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12285.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12285.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12285.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12285.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12285.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12316.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12316.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12316.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12316.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12316.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12346.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12346.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# ...
# [INFO] Optimal coadd: 4 (at 11073.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11073.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11073.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11073.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11119.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11119.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11119.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11119.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11119.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11164.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11164.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11164.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11164.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11164.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11209.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11209.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11209.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11209.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11209.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11255.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11255.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11255.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11255.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11255.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11300.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11300.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11300.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11300.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11300.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11345.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11345.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11345.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11345.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11345.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 6 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11391.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11436.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 6 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11482.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11527.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11527.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11527.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11527.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11527.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11572.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11572.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11572.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11572.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11572.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11618.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11618.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11618.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11618.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11618.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11663.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11663.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11663.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11663.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11663.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11708.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11708.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11708.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11708.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11708.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11754.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11754.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11754.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11754.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11754.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11799.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11799.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11799.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11799.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11799.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11844.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11890.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11890.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11890.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11890.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11890.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11935.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11935.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11935.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11935.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11935.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11981.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11981.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11981.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11981.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 11981.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12026.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12026.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12026.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12026.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12026.4 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12071.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12071.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12071.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12071.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12071.7 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 5 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12117.1 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 6 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12162.5 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12207.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12207.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12207.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12207.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12207.8 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12253.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12253.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12253.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12253.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12253.2 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12298.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12298.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12298.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12298.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12298.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12343.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12343.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12343.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12343.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12343.9 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12389.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12389.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12389.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12389.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12389.3 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12434.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12434.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12434.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12434.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12434.6 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12480.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12480.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12480.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12480.0 AA, initial guess=4)
# [INFO] Sky taken from static files
# [INFO] Optimal coadd: 4 (at 12480.0 AA, initial guess=4)

# %%
fig,ax = plt.subplots(1,1,figsize=(10,4))
labs = []
for d,c in zip(ifs_line[0]['dlim'], ['blue', 'red', 'orange']):
    lab = f"{d['chan']} chan dark-time S/N line {snr} "
    labs.append(lab)
    ax.plot(d['waves'], d['lmag'], color=c, ls='-')
for d,c in zip(ifs_line[1]['dlim'], ['blue', 'red', 'orange']):
    ax.plot(d['waves'], d['lmag'], color=c, ls='--')
for d,c in zip(ifs_line[2]['dlim'], ['blue', 'red', 'orange']):
    ax.plot(d['waves'], d['lmag'], color=c, ls=':')
ax.set_xlabel('Wavelength (A)')
ax.set_ylabel('Emission line flux erg/s/cm2/A')
see = 'GLAO' if full_obs['GLAO'] else f"seeing {ob['seeing']} arcsec"

integ = full_obs['NDIT']*full_obs['DIT']/1000
ax.set_title(f"IFS limiting emission flux in {integ:.0f} ksec ({full_obs['NDIT']} exp) - {see}, airmass {full_obs['AM']}, ETC {__version__}");
ax.grid()
custom_lines = [Line2D([0], [0], color='blue', lw=1),
                Line2D([0], [0], color='red', lw=1),
                Line2D([0], [0], color='black', ls='--', lw=1),
                Line2D([0], [0], color='black', ls=':', lw=1),
               ]
labs.append(f"grey time")
labs.append(f"bright time")
ax.legend(custom_lines, labs, fontsize=10,loc=1)
today = datetime.now().strftime("%Y-%m-%d")
ax.text(0.02, 0.90, f"Computed {today}", transform=ax.transAxes, size=10)
# Out:
# Text(0.02, 0.9, 'Computed 2026-07-24')

# %%
today = datetime.now().strftime("%Y-%m-%d")
outfig = os.path.join(file_dir,f"{today}_{instru.name}_IFS_limiting_Lineflux.jpg")
fig.savefig(outfig, bbox_inches='tight')
print(f"Saved file {outfig}")

outres = os.path.join(file_dir,f"{today}_{instru.name}_IFS_limiting_Lineflux.json")
with open(outres, "w") as f:
    json.dump(ifs_line, f, indent=2)
print(f"Saved file {outres}")
# Out:
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_limiting_Lineflux.jpg
# Saved file /home/nbouche/Python_git/pyetc_iredmuse/images/2026-07-24_iredMUSE_IFS_limiting_Lineflux.json
